# %%
# !nvidia-smi
# Out:
# Thu Nov 16 19:15:47 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.3/645.3 kB 10.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)
#
# OS                  Linux-5.15.120+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.68 GB
# CPU                 Intel Xeon 2.30GHz
# CUDA                11.8
#
# matplotlib          ✅ 3.7.1>=3.3.0
# numpy               ✅ 1.23.5>=1.22.2
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.3>=1.4.1
# torch               ✅ 2.1.0+cu118>=1.8.0
# torchvision         ✅ 0.16.0+cu118>=0.9.0
# tqdm                ✅ 4.66.1>=4.64.0
# pandas              ✅ 1.5.3>=1.1.4
# seaborn             ✅ 0.12.2>=0.11.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="DW29fpy0JYvJh20r6RzG")
project = rf.workspace("hust-pfkie").project("soccer-player-and-ball-ver-3")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ...

# %%
# !yolo detect train data={dataset.location}/data.yaml model=yolov8m.pt epochs=100 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 197MB/s]
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Download files

# %%
from google.colab import files
import shutil

shutil.make_archive("runs", 'zip', "runs")
files.download("runs.zip")

# %%
# !unzip runs.zip -d /content/runs

# %%
# !unzip test.zip -d /content/Soccer-Player-And-Ball-Ver-3-1

# %%
# !yolo detect val model=/content/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/Soccer-Player-And-Ball-Ver-3-1/valid/labels.cache... 612 images, 0 backgrounds, 0 corrupt: 100% 612/612 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 39/39 [00:28<00:00,  1.35it/s]
#                    all        612      13533       0.89      0.797      0.827      0.505
#                   ball        612        397      0.726      0.266      0.355      0.108
#             goalkeeper        612        422      0.937      0.981      0.988        0.6
#                 player        612      12092      0.951      0.979      0.989      0.666
#                referee        612        622      0.946       0.96      0.977      0.647
# Speed: 1.0ms preprocess, 11.8ms inference, 0.0ms loss, 3.5ms postprocess per image
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt source=/content/Soccer-Player-And-Ball-Ver-3-1/test/images
# Out:
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/34 /content/Soccer-Player-And-Ball-Ver-3-1/test/images/08fd33_0_7_png_jpg.rf.f99d59ab5f666b94b3c7fe6d12d1113e.jpg: 640x640 2 balls, 8 goalkeepers, 18 players, 37.0ms
# image 2/34 /content/Soccer-Player-And-Ball-Ver-3-1/test/images/08fd33_3_10_png_jpg.rf.3a504cd4bb5841c979b85ca3e50552d0.jpg: 640x640 11 goalkeepers, 11 players, 35.1ms
# image 3/34 /content/Soccer-Player-And-Ball-Ver-3-1/test/images/121364_9_5_png_jpg.rf.cf0768d34af2213cdceea28ae7055bc5.jpg: 640x640 10 goalkeepers, 14 players, 1 referee, 32.7ms
# image 4/34 /content/Soccer-Player-And-Ball-Ver-3-1/test/images/121364_9_7_png_jpg.rf.f2c887440f7ddb533077010e5f467e05.jpg: 640x640 11 goalkeepers, 10 players, 32.6ms
# ...
